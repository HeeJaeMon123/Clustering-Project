# %%
from selenium import webdriver
from pandas.io.html import read_html
import time
import pandas as pd
import numpy as np

browser = webdriver.Chrome("./chromedriver.exe")
browser.get("https://1xbet.whoscored.com/Regions/108/Tournaments/5/Seasons/8735/Stages/19982/PlayerStatistics/Italy-Serie-A-2021-2022")

def defensive():
    time.sleep(1)
    defense = browser.find_element_by_link_text('Defensive')
    defense.click()

    time.sleep(1)
    all_player = browser.find_element_by_link_text('All players')
    all_player.click()

    time.sleep(2)
    page = browser.find_element_by_link_text('last')
    total_page = int(page.get_attribute('data-page'))

    df_defensive = pd.DataFrame(columns = ['Player', 'Player.1', 'Apps', 'Mins', 'Tackles', 'Inter', 'Fouls',
           'Offsides', 'Clear', 'Drb', 'Blocks', 'OwnG', 'Rating'])

        #crawling the table
    for i in np.arange(total_page)+1 :
        time.sleep(1)
        table = browser.find_element_by_xpath('//*[@id="statistics-table-defensive"]')
        table_html= table.get_attribute('innerHTML')
        df2 = read_html(table_html)[0]
        df_defensive = pd.concat([df_defensive, df2], axis=0)
        browser.find_element_by_link_text('next').click()
    
    return df_defensive

def offensive():
    time.sleep(1)
    defense = browser.find_element_by_link_text('Offensive')
    defense.click()

    time.sleep(1)
    all_player = browser.find_element_by_link_text('All players')
    all_player.click()

    time.sleep(2)
    page = browser.find_element_by_link_text('last')
    total_page = int(page.get_attribute('data-page'))

    df_offensive = pd.DataFrame(columns = ['Player', 'Player.1', 'Apps', 'Mins', 'Goals', 'Assists', 'SpG',
           'KeyP', 'Drb', 'Fouled', 'Off', 'Disp', 'UnsTch', 'Rating'])

        #crawling the table
    for i in np.arange(total_page)+1 :
        time.sleep(1)
        table = browser.find_element_by_xpath('//*[@id="statistics-table-offensive"]')
        table_html= table.get_attribute('innerHTML')
        df2 = read_html(table_html)[0]
        df_offensive = pd.concat([df_offensive, df2], axis=0)
        browser.find_element_by_link_text('next').click()
    
    return df_offensive

df1 = defensive()
df2 = offensive()
df1 = pd.concat([df1,df2],axis=1)   
df1 = df1.T.drop_duplicates().T
print(df1)
print(df1.columns)
# Out:
#                                       Player  \
# 0      1Mattia ZaccagniVerona, 26, AM(CL),FW
# 1          2Lorenzo PellegriniRoma, 25, M(C)
# 2       3Paulo DybalaJuventus, 27, AM(CR),FW
# 3                    4BremerTorino, 24, D(C)
# 4   5Sergej Milinkovic-SavicLazio, 26, AM(C)
# ..                                       ...
# 1    492Junior MessiasAC Milan, 30, AM(C),FW
# 2    493Nicola MurruSampdoria, 26, D(L),M(L)
# 3             494Stefan RaduLazio, 35, D(CL)
# 4      495Ramzi AyaSalernitana, 31, Defender
# 5         496Boris RadunovicCagliari, 25, GK
#
#                                     Player.1   Apps Mins Tackles Inter Fouls  \
# 0      Mattia Zaccagni Verona, 26, AM(CL),FW      2  180     1.5     2   0.5
# 1          Lorenzo Pellegrini Roma, 25, M(C)     11  983     1.2   0.5     2
# 2       Paulo Dybala Juventus, 27, AM(CR),FW   8(1)  666     0.7   0.4   0.7
# 3                    Bremer Torino, 24, D(C)     11  974     1.9   3.9   1.8
# ...

# %%
df1.reset_index(drop=True, inplace=True)

# %%
df1
# Out:
#                                        Player  \
# 0       1Mattia ZaccagniVerona, 26, AM(CL),FW
# 1           2Lorenzo PellegriniRoma, 25, M(C)
# 2        3Paulo DybalaJuventus, 27, AM(CR),FW
# 3                     4BremerTorino, 24, D(C)
# 4    5Sergej Milinkovic-SavicLazio, 26, AM(C)
# ..                                        ...
# 491   492Junior MessiasAC Milan, 30, AM(C),FW
# 492   493Nicola MurruSampdoria, 26, D(L),M(L)
# 493            494Stefan RaduLazio, 35, D(CL)
# 494     495Ramzi AyaSalernitana, 31, Defender
# 495        496Boris RadunovicCagliari, 25, GK
#
#                                      Player.1   Apps Mins Tackles Inter Fouls  \
# 0       Mattia Zaccagni Verona, 26, AM(CL),FW      2  180     1.5     2   0.5
# 1           Lorenzo Pellegrini Roma, 25, M(C)     11  983     1.2   0.5     2
# 2        Paulo Dybala Juventus, 27, AM(CR),FW   8(1)  666     0.7   0.4   0.7
# 3                     Bremer Torino, 24, D(C)     11  974     1.9   3.9   1.8
# ...
